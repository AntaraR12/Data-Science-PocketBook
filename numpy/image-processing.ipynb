# %% [markdown]
# ### Importing all the required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\antrawat\\Documents\\GitHub\\Data-Science-PocketBook\\numpy'

# %%
cutie = np.array(plt.imread(r'C:\Users\antrawat\Documents\GitHub\Data-Science-PocketBook\data\dog.jpeg'))

# %%
plt.imshow(cutie)

# %% [markdown]
# ## reversing the image
# (depth -1)

# %%
plt.imshow(cutie[::-1,::,::])

# %% [markdown]
# ## cropping image

# %%
plt.imshow(cutie[50:250:,150:450:,::])

# %% [markdown]
# ## Bluring the image

# %%
plt.imshow(cutie[::10,::10,::])

# %% [markdown]
# ## Negative image

# %%
cutie_neg = plt.imshow(255-cutie)

# %% [markdown]
# ## hiding bow tie

# %%
cutie_remove = cutie.copy()
cutie_remove[250:370:, 210:370, ::] = 300
plt.imshow(cutie_remove)
# Out:
# C:\Users\antrawat\AppData\Local\Temp\ipykernel_7140\1340352389.py:2: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 300 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)`
# will give the desired result (the cast overflows).
#   cutie_remove[250:370:, 210:370, ::] = 300
